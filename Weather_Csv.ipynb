# %%
# PANDAS PROJECT 1

# %%
import pandas as pd
df=pd.read_csv('/content/Project 1 - Weather Dataset.csv')
df.head(3)
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df['Weather'].nunique()
# Out:
# 50

# %%
#  for counting data repiting times
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# #find all the unique wind speed values

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Weather'].value_counts().head(5).plot(kind="bar");

# %%
df[df['Weather']=="Clear"].shape[0]
# Out:
# 1326

# %%
# GROUP BY the same questions
df.groupby('Weather').get_group('Clear').shape[0]
d=df.groupby('Weather').get_group('Clear')
d.shape[0]
# Out:
# 1326

# %%
#find wind speed eqal to 4 km
df[df['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#RENAME THE COLUMN NAME 'Wearther' to 'Weather_condition'.
df.rename(columns={'Weather':'Weather_condition'},inplace=True)
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.rename(columns={"Temp_C" : "Temperature"},inplace=True)
df
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 0        1/1/2012 0:00         -1.8              -3.9         86
# 1        1/1/2012 1:00         -1.8              -3.7         87
# 2        1/1/2012 2:00         -1.8              -3.4         89
# 3        1/1/2012 3:00         -1.5              -3.2         88
# 4        1/1/2012 4:00         -1.5              -3.3         88
# ...                ...          ...               ...        ...
# 8779  12/31/2012 19:00          0.1              -2.7         81
# 8780  12/31/2012 20:00          0.2              -2.4         83
# 8781  12/31/2012 21:00         -0.5              -1.5         93
# 8782  12/31/2012 22:00         -0.2              -1.8         89
# 8783  12/31/2012 23:00          0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather_condition
# 0                   4            8.0     101.24                   Fog
# ...

# %%
# WHAT IS THE AVG 'VISIBILITY' ?
sum(df['Visibility_km'])/len(df["Visibility_km"])
# Out:
# 27.664446721311474

# %%
df.Visibility_km.mean()
# Out:
# np.float64(27.664446721311478)

# %%
# FIND ALL INSTANCES WHEN 'SNOW' WAS RECORDED
df[df['Weather_condition']=='Snow']
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 55       1/3/2012 7:00        -14.0             -19.5         63
# 84      1/4/2012 12:00        -13.7             -21.7         51
# 86      1/4/2012 14:00        -11.3             -19.0         53
# 87      1/4/2012 15:00        -10.2             -16.3         61
# 88      1/4/2012 16:00         -9.4             -15.5         61
# ...                ...          ...               ...        ...
# 8779  12/31/2012 19:00          0.1              -2.7         81
# 8780  12/31/2012 20:00          0.2              -2.4         83
# 8781  12/31/2012 21:00         -0.5              -1.5         93
# 8782  12/31/2012 22:00         -0.2              -1.8         89
# 8783  12/31/2012 23:00          0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 55                 19           25.0     100.95              Snow
# ...

# %%
# STR CONTAINS
df[df['Weather_condition'].str.contains('Snow')]
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 41      1/2/2012 17:00         -2.1              -9.5         57
# 44      1/2/2012 20:00         -5.6             -13.4         54
# 45      1/2/2012 21:00         -5.8             -12.8         58
# 47      1/2/2012 23:00         -7.4             -14.1         59
# 48       1/3/2012 0:00         -9.0             -16.0         57
# ...                ...          ...               ...        ...
# 8779  12/31/2012 19:00          0.1              -2.7         81
# 8780  12/31/2012 20:00          0.2              -2.4         83
# 8781  12/31/2012 21:00         -0.5              -1.5         93
# 8782  12/31/2012 22:00         -0.2              -1.8         89
# 8783  12/31/2012 23:00          0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 41                 22           25.0      99.66      Snow Showers
# ...

# %%
# find all the instances when "wind speed" is above 24 and "visibility" is 25
df[(df["Wind Speed_km/h"]>24)&(df["Visibility_km"]==25)]
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 23      1/1/2012 23:00          5.3               2.0         79
# 24       1/2/2012 0:00          5.2               1.5         77
# 25       1/2/2012 1:00          4.6               0.0         72
# 26       1/2/2012 2:00          3.9              -0.9         71
# 27       1/2/2012 3:00          3.7              -1.5         69
# ...                ...          ...               ...        ...
# 8705  12/28/2012 17:00         -8.6             -12.0         76
# 8753  12/30/2012 17:00        -12.1             -15.8         74
# 8755  12/30/2012 19:00        -13.4             -16.5         77
# 8759  12/30/2012 23:00        -12.1             -15.1         78
# 8760   12/31/2012 0:00        -11.1             -14.4         77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 23                 30           25.0      99.31            Cloudy
# ...

# %%
# MEAN VALUE OF EACH COLUMN AGAINST EACH Weather_Condition
df.groupby("Weather_condition").mean("numeric_only")
# Out:
#                                          Temperature  Dew Point Temp_C  \
# Weather_condition
# Clear                                       6.825716          0.089367
# Cloudy                                      7.970544          2.375810
# Drizzle                                     7.353659          5.504878
# Drizzle,Fog                                 8.067500          7.033750
# Drizzle,Ice Pellets,Fog                     0.400000         -0.700000
# Drizzle,Snow                                1.050000          0.150000
# Drizzle,Snow,Fog                            0.693333          0.120000
# Fog                                         4.303333          3.159333
# Freezing Drizzle                           -5.657143         -8.000000
# Freezing Drizzle,Fog                       -2.533333         -4.183333
# Freezing Drizzle,Haze                      -5.433333         -8.000000
# Freezing Drizzle,Snow                      -5.109091         -7.072727
# ...

# %%
# find max and min against each weather condition
df.groupby("Weather_condition").agg(['min','max'])
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather_condition
# Clear                                      1/11/2012 1:00     9/9/2012 5:00
# Cloudy                                     1/1/2012 17:00    9/9/2012 23:00
# Drizzle                                   1/23/2012 21:00    9/30/2012 3:00
# Drizzle,Fog                               1/23/2012 20:00    9/30/2012 2:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/17/2012 15:00  12/19/2012 18:00
# Drizzle,Snow,Fog                         12/18/2012 21:00   12/22/2012 3:00
# Fog                                         1/1/2012 0:00    9/22/2012 0:00
# Freezing Drizzle                          1/13/2012 10:00     2/1/2012 5:00
# Freezing Drizzle,Fog                        1/1/2012 2:00   12/10/2012 5:00
# ...

# %%
# weathe condition in fog
df.groupby("Weather_condition").get_group("Fog")
df[df["Weather_condition"]=="Fog"]
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 0        1/1/2012 0:00         -1.8              -3.9         86
# 1        1/1/2012 1:00         -1.8              -3.7         87
# 4        1/1/2012 4:00         -1.5              -3.3         88
# 5        1/1/2012 5:00         -1.4              -3.3         87
# 6        1/1/2012 6:00         -1.5              -3.1         89
# ...                ...          ...               ...        ...
# 8716   12/29/2012 4:00        -16.0             -17.2         90
# 8717   12/29/2012 5:00        -14.8             -15.9         91
# 8718   12/29/2012 6:00        -13.8             -15.3         88
# 8719   12/29/2012 7:00        -14.8             -16.4         88
# 8722  12/29/2012 10:00        -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 0                   4            8.0     101.24               Fog
# ...

# %%
# find ball instance when weather copndition is clera and visibility is above 40 km/h
df[(df["Weather_condition"]=="Clear")|(df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 67      1/3/2012 19:00        -16.9             -24.8         50
# 106     1/5/2012 10:00         -6.0             -10.0         73
# 107     1/5/2012 11:00         -5.6             -10.2         70
# 108     1/5/2012 12:00         -4.7              -9.6         69
# 109     1/5/2012 13:00         -4.4              -9.7         66
# ...                ...          ...               ...        ...
# 8749  12/30/2012 13:00        -12.4             -16.2         73
# 8750  12/30/2012 14:00        -11.8             -16.1         70
# 8751  12/30/2012 15:00        -11.3             -15.6         70
# 8752  12/30/2012 16:00        -11.4             -15.5         72
# 8756  12/30/2012 20:00        -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 67                 24           25.0     101.74             Clear
# ...

# %%
df[(df["Weather_condition"]== 'Clear') & (df['Rel Hum_%'] >50) | (df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  Rel Hum_%  \
# 106     1/5/2012 10:00         -6.0             -10.0         73
# 107     1/5/2012 11:00         -5.6             -10.2         70
# 108     1/5/2012 12:00         -4.7              -9.6         69
# 109     1/5/2012 13:00         -4.4              -9.7         66
# 110     1/5/2012 14:00         -5.1             -10.7         65
# ...                ...          ...               ...        ...
# 8749  12/30/2012 13:00        -12.4             -16.2         73
# 8750  12/30/2012 14:00        -11.8             -16.1         70
# 8751  12/30/2012 15:00        -11.3             -15.6         70
# 8752  12/30/2012 16:00        -11.4             -15.5         72
# 8756  12/30/2012 20:00        -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 106                17           48.3     100.45      Mainly Clear
# ...
